# %% [markdown]
# # Generated Content Detector Project: AI generated photos vs real photos
# ## Pytorch CNN model - Final Version

# %% [markdown]
# ### Import libraries

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torchsummary import summary
from torch.utils.data import Dataset, DataLoader, Subset
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch
import matplotlib.pyplot as plt
import numpy as np
import os
from PIL import Image
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pickle
print(torch.cuda.is_available())
# Out:
# True

# %% [markdown]
# ### Download the dataset
# ###### !gdown command to downloads a specific file from Google Drive using its unique file ID, 1u4xb45DdfP80kxJ20DV20qAGyhcDaCDL, directly into the current working directory of the Jupyter notebook:

# %%
# !gdown 1u4xb45DdfP80kxJ20DV20qAGyhcDaCDL
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1u4xb45DdfP80kxJ20DV20qAGyhcDaCDL
# From (redirected): https://drive.google.com/uc?id=1u4xb45DdfP80kxJ20DV20qAGyhcDaCDL&confirm=t&uuid=ba643dcc-5e83-4710-bebd-738a19355bca
# To: /content/AI-face-detection-Dataset-v3.zip
# 100% 1.12G/1.12G [00:12<00:00, 87.0MB/s]

# %% [markdown]
# ###### !unzip command extracts the contents of the ZIP file located at /content/AI-face-detection-Dataset-v3.zip in a Jupyter notebook, decompressing it into the same directory:

# %%
# !unzip /content/AI-face-detection-Dataset-v3.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0557.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0557.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/SFHQ_pt4_00002493.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._SFHQ_pt4_00002493.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/959_20241130175954_A_close-up_shot_of_a_elderly_non-binary_person_of_.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._959_20241130175954_A_close-up_shot_of_a_elderly_non-binary_person_of_.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/93_20241130141644_A_close-up_shot_of_a_young_adult_female_person_of_.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._93_20241130141644_A_close-up_shot_of_a_young_adult_female_person_of_.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1107.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1107.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0219.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0219.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/image_686.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._image_686.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1113.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1113.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/370_20241130152415_A_close-up_shot_of_a_elderly_genderqueer_person_of.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._370_20241130152415_A_close-up_shot_of_a_elderly_genderqueer_person_of.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0599.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0599.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0572.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0572.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0580.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0580.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/594_20241130162537_A_close-up_shot_of_a_young_adult_non-binary_person.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._594_20241130162537_A_close-up_shot_of_a_young_adult_non-binary_person.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0214.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0214.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0200.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0200.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/944_20241130175604_A_close-up_shot_of_a_teenager_male_person_of_Afric.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._944_20241130175604_A_close-up_shot_of_a_teenager_male_person_of_Afric.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0594.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0594.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/686_20241130164932_A_close-up_shot_of_a_teenager_male_person_of_Afric.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._686_20241130164932_A_close-up_shot_of_a_teenager_male_person_of_Afric.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/hard_31_0011.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._hard_31_0011.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0566.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0566.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0228.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0228.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1136.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1136.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/48_20241130140629_A_close-up_shot_of_a_middle-aged_genderqueer_perso.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._48_20241130140629_A_close-up_shot_of_a_middle-aged_genderqueer_perso.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/54_20241130140750_A_close-up_shot_of_a_middle-aged_female_person_of_.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._54_20241130140750_A_close-up_shot_of_a_middle-aged_female_person_of_.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1122.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1122.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/280_20241130150434_A_close-up_shot_of_a_young_adult_non-binary_person.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._280_20241130150434_A_close-up_shot_of_a_young_adult_non-binary_person.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/787_20241130171433_A_close-up_shot_of_a_elderly_non-binary_person_of_.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._787_20241130171433_A_close-up_shot_of_a_elderly_non-binary_person_of_.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/Female_25.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._Female_25.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0543.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0543.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/2_20241130135618_A_close-up_shot_of_a_teenager_female_person_of_Pac.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._2_20241130135618_A_close-up_shot_of_a_teenager_female_person_of_Pac.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0225.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0225.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0231.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0231.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/294_20241130150730_A_close-up_shot_of_a_middle-aged_non-binary_person.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._294_20241130150730_A_close-up_shot_of_a_middle-aged_non-binary_person.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/Female_31.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._Female_31.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0557.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0557.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/image_112.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._image_112.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/Female_19.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._Female_19.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0219.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0219.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1107.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1107.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/169_20241130143502_A_close-up_shot_of_a_child_female_person_of_Pacifi.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._169_20241130143502_A_close-up_shot_of_a_child_female_person_of_Pacifi.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1113.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1113.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/image_106.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._image_106.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0599.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0599.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1308.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1308.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0016.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0016.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/image_57.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._image_57.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/829_20241130172810_A_close-up_shot_of_a_teenager_male_person_of_Asian.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._829_20241130172810_A_close-up_shot_of_a_teenager_male_person_of_Asian.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0782.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0782.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0770.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0770.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0764.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0764.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1488.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1488.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/441_20241130154308_A_close-up_shot_of_a_teenager_non-binary_person_of.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._441_20241130154308_A_close-up_shot_of_a_teenager_non-binary_person_of.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/517_20241130160532_A_close-up_shot_of_a_elderly_genderqueer_person_of.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._517_20241130160532_A_close-up_shot_of_a_elderly_genderqueer_person_of.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0796.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0796.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/18_20241130135928_A_close-up_shot_of_a_middle-aged_female_person_of_.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._18_20241130135928_A_close-up_shot_of_a_middle-aged_female_person_of_.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/image_43.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._image_43.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/426_20241130153847_A_close-up_shot_of_a_teenager_female_person_of_Cau.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._426_20241130153847_A_close-up_shot_of_a_teenager_female_person_of_Cau.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0002.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0002.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1334.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1334.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0994.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0994.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1452.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1452.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0966.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0966.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/SFHQ_pt4_00002688.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._SFHQ_pt4_00002688.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0972.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0972.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0758.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0758.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0980.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0980.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1446.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1446.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1320.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1320.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/hard_136_1101.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._hard_136_1101.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/image_94.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._image_94.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1339.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1339.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/hard_5_1111.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._hard_5_1111.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0027.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0027.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/SFHQ_pt4_00002677.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._SFHQ_pt4_00002677.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0741.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0741.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/3_20241130135629_A_close-up_shot_of_a_child_genderqueer_person_of_A.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._3_20241130135629_A_close-up_shot_of_a_child_genderqueer_person_of_A.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0999.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0999.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0755.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0755.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/SFHQ_pt4_00002663.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._SFHQ_pt4_00002663.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/hard_4_1111.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._hard_4_1111.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/303_20241130150929_A_close-up_shot_of_a_child_non-binary_person_of_Pa.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._303_20241130150929_A_close-up_shot_of_a_child_non-binary_person_of_Pa.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0033.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0033.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1305.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1305.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/hard_93_1111.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._hard_93_1111.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/45_20241130140543_A_close-up_shot_of_a_young_adult_female_person_of_.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._45_20241130140543_A_close-up_shot_of_a_young_adult_female_person_of_.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1463.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1463.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/Male_47.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._Male_47.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0957.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0957.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1491.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1491.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0943.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0943.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1485.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1485.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/image_304.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._image_304.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0769.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0769.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1477.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1477.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/Male_53.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._Male_53.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1311.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1311.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0162.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0162.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0190.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0190.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/84_20241130141437_A_close-up_shot_of_a_elderly_non-binary_person_of_.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._84_20241130141437_A_close-up_shot_of_a_elderly_non-binary_person_of_.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/666_20241130164502_A_close-up_shot_of_a_young_adult_male_person_of_Na.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._666_20241130164502_A_close-up_shot_of_a_young_adult_male_person_of_Na.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0604.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0604.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0610.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0610.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0184.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0184.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0176.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0176.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1268.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1268.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/780_20241130171255_A_close-up_shot_of_a_young_adult_non-binary_person.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._780_20241130171255_A_close-up_shot_of_a_young_adult_non-binary_person.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/810_20241130172151_A_close-up_shot_of_a_young_adult_genderqueer_perso.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._810_20241130172151_A_close-up_shot_of_a_young_adult_genderqueer_perso.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1240.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1240.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/195_20241130144154_A_close-up_shot_of_a_elderly_genderqueer_person_of.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._195_20241130144154_A_close-up_shot_of_a_elderly_genderqueer_person_of.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0638.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0638.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/31_20241130140225_A_close-up_shot_of_a_young_adult_non-binary_person.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._31_20241130140225_A_close-up_shot_of_a_young_adult_non-binary_person.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0812.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0812.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0806.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0806.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/173_20241130143541_A_close-up_shot_of_a_middle-aged_non-binary_person.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._173_20241130143541_A_close-up_shot_of_a_middle-aged_non-binary_person.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1254.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1254.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/hard_109_1100.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._hard_109_1100.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0153.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0153.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0635.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0635.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/SFHQ_pt4_00002703.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._SFHQ_pt4_00002703.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/SFHQ_pt4_00002717.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._SFHQ_pt4_00002717.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0621.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0621.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0147.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0147.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1259.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1259.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1283.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1283.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1271.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1271.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/764_20241130170858_A_close-up_shot_of_a_middle-aged_male_person_of_As.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._764_20241130170858_A_close-up_shot_of_a_middle-aged_male_person_of_As.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/hard_114_1111.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._hard_114_1111.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0609.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0609.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0823.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0823.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0837.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0837.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1265.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1265.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1297.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1297.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/28_20241130140151_A_close-up_shot_of_a_young_adult_genderqueer_perso.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._28_20241130140151_A_close-up_shot_of_a_young_adult_genderqueer_perso.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0189.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0189.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/image_516.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._image_516.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0406.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0406.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0392.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0392.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0360.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0360.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0374.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0374.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0386.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0386.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/888_20241130174407_A_close-up_shot_of_a_young_adult_non-binary_person.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._888_20241130174407_A_close-up_shot_of_a_young_adult_non-binary_person.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1098.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1098.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0412.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0412.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1042.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1042.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1056.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1056.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0348.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0348.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/860_20241130173731_A_close-up_shot_of_a_elderly_genderqueer_person_of.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._860_20241130173731_A_close-up_shot_of_a_elderly_genderqueer_person_of.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/607_20241130162915_A_close-up_shot_of_a_young_adult_genderqueer_perso.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._607_20241130162915_A_close-up_shot_of_a_young_adult_genderqueer_perso.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/SFHQ_pt4_00002501.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._SFHQ_pt4_00002501.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0437.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0437.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0351.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0351.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0345.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0345.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/585_20241130162231_A_close-up_shot_of_a_young_adult_genderqueer_perso.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._585_20241130162231_A_close-up_shot_of_a_young_adult_genderqueer_perso.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0423.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0423.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/518_20241130160547_A_close-up_shot_of_a_middle-aged_genderqueer_perso.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._518_20241130160547_A_close-up_shot_of_a_middle-aged_genderqueer_perso.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/SFHQ_pt4_00002515.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._SFHQ_pt4_00002515.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/621_20241130163352_A_close-up_shot_of_a_child_non-binary_person_of_Mi.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._621_20241130163352_A_close-up_shot_of_a_child_non-binary_person_of_Mi.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1073.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1073.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1081.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1081.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1095.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1095.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1067.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1067.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0379.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0379.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/SFHQ_pt4_00002529.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._SFHQ_pt4_00002529.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/630_20241130163654_A_close-up_shot_of_a_middle-aged_non-binary_person.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._630_20241130163654_A_close-up_shot_of_a_middle-aged_non-binary_person.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0378.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0378.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1066.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1066.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1094.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1094.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/143_20241130142940_A_close-up_shot_of_a_child_genderqueer_person_of_C.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._143_20241130142940_A_close-up_shot_of_a_child_genderqueer_person_of_C.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/SFHQ_pt4_00002528.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._SFHQ_pt4_00002528.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/23_20241130140035_A_close-up_shot_of_a_young_adult_non-binary_person.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._23_20241130140035_A_close-up_shot_of_a_young_adult_non-binary_person.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1080.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1080.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1072.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1072.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/420_20241130153729_A_close-up_shot_of_a_middle-aged_male_person_of_Pa.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._420_20241130153729_A_close-up_shot_of_a_middle-aged_male_person_of_Pa.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0344.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0344.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/782_20241130171328_A_close-up_shot_of_a_child_genderqueer_person_of_C.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._782_20241130171328_A_close-up_shot_of_a_child_genderqueer_person_of_C.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/SFHQ_pt4_00002514.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._SFHQ_pt4_00002514.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0422.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0422.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/369_20241130152405_A_close-up_shot_of_a_elderly_genderqueer_person_of.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._369_20241130152405_A_close-up_shot_of_a_elderly_genderqueer_person_of.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0436.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0436.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/SFHQ_pt4_00002500.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._SFHQ_pt4_00002500.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0350.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0350.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0349.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0349.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/923_20241130175112_A_close-up_shot_of_a_middle-aged_non-binary_person.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._923_20241130175112_A_close-up_shot_of_a_middle-aged_non-binary_person.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1057.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1057.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/587_20241130162309_A_close-up_shot_of_a_young_adult_genderqueer_perso.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._587_20241130162309_A_close-up_shot_of_a_young_adult_genderqueer_perso.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/769_20241130171025_A_close-up_shot_of_a_middle-aged_genderqueer_perso.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._769_20241130171025_A_close-up_shot_of_a_middle-aged_genderqueer_perso.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/58_20241130140840_A_close-up_shot_of_a_elderly_male_person_of_Asian_.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._58_20241130140840_A_close-up_shot_of_a_elderly_male_person_of_Asian_.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1043.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1043.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1099.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1099.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0387.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0387.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0375.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0375.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/140_20241130142857_A_close-up_shot_of_a_teenager_non-binary_person_of.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._140_20241130142857_A_close-up_shot_of_a_teenager_non-binary_person_of.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0413.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0413.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/975_20241130180321_A_close-up_shot_of_a_middle-aged_genderqueer_perso.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._975_20241130180321_A_close-up_shot_of_a_middle-aged_genderqueer_perso.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/333_20241130151600_A_close-up_shot_of_a_young_adult_genderqueer_perso.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._333_20241130151600_A_close-up_shot_of_a_young_adult_genderqueer_perso.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0407.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0407.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0361.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0361.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/335_20241130151640_A_close-up_shot_of_a_teenager_female_person_of_Asi.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._335_20241130151640_A_close-up_shot_of_a_teenager_female_person_of_Asi.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0393.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0393.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0836.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0836.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/image_517.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._image_517.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0188.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0188.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/hard_115_1110.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._hard_115_1110.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1296.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1296.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1264.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1264.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1270.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1270.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/752_20241130170532_A_close-up_shot_of_a_teenager_male_person_of_Middl.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._752_20241130170532_A_close-up_shot_of_a_teenager_male_person_of_Middl.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1282.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1282.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0822.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0822.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0608.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0608.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0620.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0620.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/SFHQ_pt4_00002716.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._SFHQ_pt4_00002716.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1258.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1258.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0146.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0146.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/hard_210_1100.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._hard_210_1100.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0152.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0152.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/SFHQ_pt4_00002702.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._SFHQ_pt4_00002702.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0634.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0634.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/214_20241130144629_A_close-up_shot_of_a_middle-aged_non-binary_person.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._214_20241130144629_A_close-up_shot_of_a_middle-aged_non-binary_person.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/483_20241130155614_A_close-up_shot_of_a_middle-aged_male_person_of_Af.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._483_20241130155614_A_close-up_shot_of_a_middle-aged_male_person_of_Af.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0807.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0807.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1255.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1255.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1241.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1241.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0813.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0813.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0639.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0639.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/359_20241130152210_A_close-up_shot_of_a_young_adult_non-binary_person.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._359_20241130152210_A_close-up_shot_of_a_young_adult_non-binary_person.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/331_20241130151529_A_close-up_shot_of_a_teenager_non-binary_person_of.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._331_20241130151529_A_close-up_shot_of_a_teenager_non-binary_person_of.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0611.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0611.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1269.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1269.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0177.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0177.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0185.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0185.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/618_20241130163312_A_close-up_shot_of_a_child_female_person_of_Native.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._618_20241130163312_A_close-up_shot_of_a_child_female_person_of_Native.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0191.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0191.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/453_20241130154637_A_close-up_shot_of_a_elderly_female_person_of_Cauc.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._453_20241130154637_A_close-up_shot_of_a_elderly_female_person_of_Cauc.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0163.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0163.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0605.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0605.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/555_20241130161405_A_close-up_shot_of_a_elderly_genderqueer_person_of.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._555_20241130161405_A_close-up_shot_of_a_elderly_genderqueer_person_of.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/Male_52.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._Male_52.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1476.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1476.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0768.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0768.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/image_305.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._image_305.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1484.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1484.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0942.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0942.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1310.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1310.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/hard_46_0011.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._hard_46_0011.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1304.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1304.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1490.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1490.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0956.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0956.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/Male_46.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._Male_46.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1462.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1462.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/SFHQ_pt4_00002662.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._SFHQ_pt4_00002662.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0754.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0754.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/19_20241130135941_A_close-up_shot_of_a_middle-aged_female_person_of_.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._19_20241130135941_A_close-up_shot_of_a_middle-aged_female_person_of_.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0032.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0032.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/image_81.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._image_81.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0026.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0026.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1338.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1338.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/image_95.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._image_95.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0998.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0998.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0740.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0740.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/SFHQ_pt4_00002676.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._SFHQ_pt4_00002676.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1447.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1447.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0981.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0981.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/hard_203_0010.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._hard_203_0010.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0759.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0759.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0973.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0973.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/hard_165_1000.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._hard_165_1000.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1321.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1321.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1335.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1335.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/467_20241130155038_A_close-up_shot_of_a_middle-aged_non-binary_person.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._467_20241130155038_A_close-up_shot_of_a_middle-aged_non-binary_person.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/SFHQ_pt4_00002689.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._SFHQ_pt4_00002689.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0967.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0967.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1453.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1453.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/hard_164_1000.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._hard_164_1000.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0995.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0995.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0797.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0797.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1489.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1489.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0765.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0765.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0003.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0003.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/image_42.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._image_42.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/image_56.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._image_56.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0017.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0017.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/679_20241130164806_A_close-up_shot_of_a_middle-aged_male_person_of_Af.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._679_20241130164806_A_close-up_shot_of_a_middle-aged_male_person_of_Af.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1309.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1309.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0771.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0771.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0783.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0783.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1112.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1112.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/image_661.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._image_661.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0598.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0598.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/image_107.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._image_107.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/Female_18.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._Female_18.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/image_113.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._image_113.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1106.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1106.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0218.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0218.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/64_20241130140955_A_close-up_shot_of_a_teenager_non-binary_person_of.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._64_20241130140955_A_close-up_shot_of_a_teenager_non-binary_person_of.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0230.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0230.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0556.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0556.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/407_20241130153409_A_close-up_shot_of_a_middle-aged_genderqueer_perso.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._407_20241130153409_A_close-up_shot_of_a_middle-aged_genderqueer_perso.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/Female_30.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._Female_30.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0542.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0542.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/Female_24.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._Female_24.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0224.jpg
# ...
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1233.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1233.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/133_20241130142644_A_close-up_shot_of_a_elderly_genderqueer_person_of.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._133_20241130142644_A_close-up_shot_of_a_elderly_genderqueer_person_of.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/42_20241130140451_A_close-up_shot_of_a_teenager_non-binary_person_of.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._42_20241130140451_A_close-up_shot_of_a_teenager_non-binary_person_of.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/134_20241130142704_A_close-up_shot_of_a_young_adult_male_person_of_Ca.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._134_20241130142704_A_close-up_shot_of_a_young_adult_male_person_of_Ca.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/180_20241130143729_A_close-up_shot_of_a_young_adult_male_person_of_Mi.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._180_20241130143729_A_close-up_shot_of_a_young_adult_male_person_of_Mi.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1227.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1227.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0139.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0139.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/261_20241130145902_A_close-up_shot_of_a_elderly_male_person_of_Native.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._261_20241130145902_A_close-up_shot_of_a_elderly_male_person_of_Native.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0887.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0887.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0875.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0875.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/224_20241130144848_A_close-up_shot_of_a_middle-aged_male_person_of_Mi.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._224_20241130144848_A_close-up_shot_of_a_middle-aged_male_person_of_Mi.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/46_20241130140552_A_close-up_shot_of_a_child_female_person_of_Caucas.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._46_20241130140552_A_close-up_shot_of_a_child_female_person_of_Caucas.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0732.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0732.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/SFHQ_pt4_00002604.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._SFHQ_pt4_00002604.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0918.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0918.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/image_439.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._image_439.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0054.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0054.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/hard_32_1111.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._hard_32_1111.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0040.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0040.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/368_20241130152356_A_close-up_shot_of_a_child_female_person_of_Pacifi.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._368_20241130152356_A_close-up_shot_of_a_child_female_person_of_Pacifi.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/838_20241130173131_A_close-up_shot_of_a_middle-aged_genderqueer_perso.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._838_20241130173131_A_close-up_shot_of_a_middle-aged_genderqueer_perso.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/900_20241130174642_A_close-up_shot_of_a_middle-aged_genderqueer_perso.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._900_20241130174642_A_close-up_shot_of_a_middle-aged_genderqueer_perso.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1438.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1438.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/SFHQ_pt4_00002610.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._SFHQ_pt4_00002610.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0726.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0726.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0924.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0924.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1410.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1410.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/Male_34.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._Male_34.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/SFHQ_pt4_00002638.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._SFHQ_pt4_00002638.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0068.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0068.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1376.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1376.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1384.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1384.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/image_405.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._image_405.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1390.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1390.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/image_411.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._image_411.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1362.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1362.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1404.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1404.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/Male_20.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._Male_20.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0930.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0930.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/487_20241130155729_A_close-up_shot_of_a_middle-aged_female_person_of_.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._487_20241130155729_A_close-up_shot_of_a_middle-aged_female_person_of_.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0703.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0703.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0929.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0929.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1389.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1389.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/354_20241130152059_A_close-up_shot_of_a_middle-aged_female_person_of_.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._354_20241130152059_A_close-up_shot_of_a_middle-aged_female_person_of_.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0097.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0097.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/hard_196_1101.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._hard_196_1101.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0065.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0065.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/662_20241130164415_A_close-up_shot_of_a_elderly_male_person_of_Mixed_.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._662_20241130164415_A_close-up_shot_of_a_elderly_male_person_of_Mixed_.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0071.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0071.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0083.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0083.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1409.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1409.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0717.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0717.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/hard_172_1100.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._hard_172_1100.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0915.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0915.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1421.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1421.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0059.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0059.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1347.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1347.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/862_20241130173803_A_close-up_shot_of_a_child_male_person_of_Caucasia.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._862_20241130173803_A_close-up_shot_of_a_child_male_person_of_Caucasia.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/938_20241130175435_A_close-up_shot_of_a_elderly_male_person_of_Hispan.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._938_20241130175435_A_close-up_shot_of_a_elderly_male_person_of_Hispan.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1353.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1353.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/834_20241130173007_A_close-up_shot_of_a_teenager_female_person_of_Asi.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._834_20241130173007_A_close-up_shot_of_a_teenager_female_person_of_Asi.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1435.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1435.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0901.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0901.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1148.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1148.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0256.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0256.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/366_20241130152335_A_close-up_shot_of_a_middle-aged_female_person_of_.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._366_20241130152335_A_close-up_shot_of_a_middle-aged_female_person_of_.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0530.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0530.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/Female_56.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._Female_56.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0524.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0524.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/Female_42.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._Female_42.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0242.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0242.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0298.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0298.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1186.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1186.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/hard_200_1111.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._hard_200_1111.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1174.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1174.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/109_20241130142028_A_close-up_shot_of_a_child_non-binary_person_of_Af.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._109_20241130142028_A_close-up_shot_of_a_child_non-binary_person_of_Af.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/image_161.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._image_161.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/image_175.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._image_175.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0518.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0518.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/156_20241130143208_A_close-up_shot_of_a_teenager_female_person_of_Pac.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._156_20241130143208_A_close-up_shot_of_a_teenager_female_person_of_Pac.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_1160.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_1160.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/677_20241130164737_A_close-up_shot_of_a_young_adult_non-binary_person.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._677_20241130164737_A_close-up_shot_of_a_young_adult_non-binary_person.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1192.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1192.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1179.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1179.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/334_20241130151626_A_close-up_shot_of_a_young_adult_non-binary_person.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._334_20241130151626_A_close-up_shot_of_a_young_adult_non-binary_person.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0267.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0267.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/656_20241130164309_A_close-up_shot_of_a_teenager_non-binary_person_of.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._656_20241130164309_A_close-up_shot_of_a_teenager_non-binary_person_of.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0295.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0295.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0501.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0501.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0515.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0515.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/man_0281.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._man_0281.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0273.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0273.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/hard_17_1010.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._hard_17_1010.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1145.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1145.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_0529.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_0529.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/woman_1151.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._woman_1151.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/970_20241130180206_A_close-up_shot_of_a_teenager_female_person_of_His.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._970_20241130180206_A_close-up_shot_of_a_teenager_female_person_of_His.jpg
#   inflating: AI-face-detection-Dataset-v3/AI/521_20241130160650_A_close-up_shot_of_a_middle-aged_non-binary_person.jpg
#   inflating: __MACOSX/AI-face-detection-Dataset-v3/AI/._521_20241130160650_A_close-up_shot_of_a_middle-aged_non-binary_person.jpg

# %% [markdown]
# ### Determine System Device to optimize performance: CPU or CUDA (VRAM) Checker

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using:", device)
# Out:
# Using: cuda

# %% [markdown]
# ### Image Dataset Preparation with PyTorch
# ##### - Training Data: 7,000 images (3500 AI + 3500 real) - 70%
# ##### - Testing Data: 2,000 images (1000 AI + 1000 real) - 20%
# ##### - Testing Data: 1,000 images (500 AI + 500 real) - 10%

# %%
# Measure the time taken for the cell execution:
# %%time

# Set up image transformations
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# Load the dataset from the specified directory
# Note: The link to my dataset can be found in the README file located in the 'dataset' folder on GitHub
dataset = datasets.ImageFolder("/content/AI-face-detection-Dataset-v3/", transform=transform)

#############################################################################
# Load previously saved indices or datasets if available:
try:
    with open('datasets.pkl', 'rb') as f:
        data = pickle.load(f)
        train_indices = data['train_indices']
        val_indices = data['val_indices']
        test_indices = data['test_indices']
        classes = data['classes']
except FileNotFoundError:
    print("No saved dataset found, proceeding with the current run.")

################################### If loading fails, do the following steps:

# Split by class (real + ai separately)
indices_real = [i for i, (_, label) in enumerate(dataset) if label == dataset.class_to_idx["real_color"]]
indices_ai   = [i for i, (_, label) in enumerate(dataset) if label == dataset.class_to_idx["AI"]]

# Train size 70%, Validation size 10%, Test size 20%
def split_class(indices, train_ratio=0.7, val_ratio=0.1):
    train_len = int(len(indices) * train_ratio)
    val_len = int(len(indices) * val_ratio)
    return indices[:train_len], indices[train_len:train_len + val_len], indices[train_len + val_len:]

train_real, val_real, test_real = split_class(indices_real)
train_ai, val_ai, test_ai = split_class(indices_ai)

# Combine training, validation, and testing indices
train_indices = train_real + train_ai
val_indices = val_real + val_ai
test_indices = test_real + test_ai

# Prepare subsets for training, validation, and testing
train_dataset = Subset(dataset, train_indices)
val_dataset = Subset(dataset, val_indices)
test_dataset = Subset(dataset, test_indices)

# Create data loaders for batch processing
trainloader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
valloader = DataLoader(val_dataset, batch_size=32, shuffle=True, num_workers=2)  # Validation loader
testloader = DataLoader(test_dataset, batch_size=32, shuffle=True, num_workers=2)

# Retrieve class names
classes = dataset.classes   # ['ai', 'real']

# Output the number of samples in training, validation, and testing datasets
print("Train samples:", len(train_indices))
print("Validation samples:", len(val_indices))
print("Test samples:", len(test_indices))
print("Classes:", classes)

# Save the datasets and indices:
with open('datasets.pkl', 'wb') as f:
    pickle.dump({
        'train_indices': train_indices,
        'val_indices': val_indices,
        'test_indices': test_indices,
        'classes': classes
    }, f)

# Else, if loading succeeds, continue with the loaded data.
# Out:
# No saved dataset found, proceeding with the current run.
# Train samples: 6996
# Validation samples: 998
# Test samples: 2002
# Classes: ['AI', 'real_color']
# CPU times: user 9min 21s, sys: 2.83 s, total: 9min 24s
# Wall time: 2min 30s

# %% [markdown]
# ### Display Randomly Selected Images with Classifications from the Trained Model

# %%
# Functions to display an image
batch_size = 8
def imshow(img):
    img = img / 2 + 0.5     # unnormalize the image
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# Fetch some random training images
dataiter_train = iter(trainloader)
images_train, labels_train = next(dataiter_train)

# Display the training images
imshow(torchvision.utils.make_grid(images_train))

# Print the corresponding training labels
print('Train Labels: ' + ' '.join(f'{classes[labels_train[j]]:5s}' for j in range(batch_size)))

# Fetch some random validation images
dataiter_val = iter(valloader)
images_val, labels_val = next(dataiter_val)

# Display the validation images
imshow(torchvision.utils.make_grid(images_val))

# Print the corresponding validation labels
print('Validation Labels: ' + ' '.join(f'{classes[labels_val[j]]:5s}' for j in range(batch_size)))
# Out:
# Train Labels: real_color AI    AI    real_color AI    real_color AI    AI
# Validation Labels: AI    AI    real_color real_color real_color real_color AI    AI

# %% [markdown]
# ### Define a Convolutional Neural Network (CNN) for Image Classification
# ##### This code implements a convolutional neural network (CNN) class named Net, featuring two convolutional layers with pooling, followed by three fully connected layers. It is designed for binary image classification, effectively modeling the forward pass to process input images and output class predictions.

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 6, 5) # First convolutional layer
        self.pool = nn.MaxPool2d(2, 2) # Max pooling layer
        self.conv2 = nn.Conv2d(6, 16, 5) # Second convolutional layer
        self.fc1 = nn.Linear(16 * 29 * 29, 120)  # First fully connected layer
        self.fc2 = nn.Linear(120, 84) # Second fully connected layer
        self.fc3 = nn.Linear(84, 2)  # Output layer for 2 classes

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x))) # Apply first conv layer and pooling
        x = self.pool(F.relu(self.conv2(x))) # Apply second conv layer and pooling
        x = torch.flatten(x, 1) # Flatten all dimensions except batch
        x = F.relu(self.fc1(x)) # Forward pass through first fully connected layer
        x = F.relu(self.fc2(x)) # Forward pass through second fully connected layer
        x = self.fc3(x) # Output layer
        return x

# net = Net()             # Use this for CPU
net = Net().to(device)    # Move the model to GPU

# %% [markdown]
# ### Define a Loss function and optimizer

# %%
# Define the loss function for training
criterion = nn.CrossEntropyLoss() # This is used for multi-class classification

# Set up the optimizer for updating the model's parameters
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9) # Stochastic Gradient Descent with momentum

# Alternative optimizer (commented out): Adam optimizer for adaptive learning rate
# optimizer = torch.optim.Adam(net.parameters(), lr=0.001)

# %% [markdown]
# ### Training the Neural Network
# ##### This section of the code trains a neural network for image classification 100 epochs, calculating and recording the training loss at each epoch. The process utilizes a data loader to iterate through the training dataset, performs forward passes to compute outputs, calculates the loss using a defined criterion, performs backward passes to compute gradients, and updates the model weights using the specified optimizer.
#
# ##### Additionally, an early stopping mechanism is implemented, based on validation loss, to mitigate overfitting caused by high variance. This technique allows the model to terminate training when its performance on the validation set begins to degrade, preventing excessive fitting to the training data and improving generalization.

# %%
# Measure the time taken for the cell execution:
# %%time

train_losses = [] # Initialize a list to store training losses for each epoch
val_losses = []  # List to store validation losses
best_val_loss = float("inf") # Initialize best validation loss to infinity
patience = 8 # Number of epochs to wait before early stopping
epochs_no_improve = 0 # Counter for epochs without improvement in validation loss

# Loop through a specified number of epochs
for epoch in range(100):
    running_loss = 0.0  # Initialize cumulative loss for the current epoch

    # Iterate through the training data
    for i, data in enumerate(trainloader): # Iterate over the number of epochs
        inputs, labels = data  # Get the input images and their corresponding labels

        inputs = inputs.to(device)  # Move inputs to the device (GPU or CPU)
        labels = labels.to(device)  # Move labels to the device

        optimizer.zero_grad()  # Clear previous gradients

        outputs = net(inputs)  # Forward pass: compute the model's predictions

        loss = criterion(outputs, labels)  # Compute the training loss

        loss.backward()  # Backward pass: compute gradients
        optimizer.step()  # Update model parameters

        running_loss += loss.item()  # Accumulate the training loss

    epoch_loss = running_loss / len(trainloader)  # Average loss for the epoch
    train_losses.append(epoch_loss)  # Store the epoch loss
    print(f"Epoch {epoch+1}, Training loss: {epoch_loss:.4f}")  # Print the training loss for the current epoch

    # Validation phase
    net.eval()  # Set the model to evaluation mode
    val_running_loss = 0.0  # Initialize cumulative validation loss

    with torch.no_grad():  # Disable gradient calculation for validation
        for data in valloader:
            inputs, labels = data  # Get the validation images and labels
            inputs = inputs.to(device)  # Move inputs to the device
            labels = labels.to(device)  # Move labels to the device

            outputs = net(inputs)  # Forward pass: compute predictions
            loss = criterion(outputs, labels)  # Compute validation loss
            val_running_loss += loss.item()  # Accumulate validation loss

    val_epoch_loss = val_running_loss / len(valloader)  # Average validation loss for the epoch
    val_losses.append(val_epoch_loss)  # Store the validation loss
    print(f"Epoch {epoch+1}, Validation loss: {val_epoch_loss:.4f}")  # Print validation loss

    if val_epoch_loss < best_val_loss: # If the current validation loss is the best
        best_val_loss = val_epoch_loss # Update best validation loss
        epochs_no_improve = 0 # Reset the no-improve counter
        torch.save(net.state_dict(), "best_model.pth") # Save the best model
    else: # If the validation loss did not improve
        epochs_no_improve += 1 # Increment the no-improve counter
        if epochs_no_improve >= patience: # Check if patience limit is reached
            print("Early stopping") # Indicate early stopping condition met
            break  # Exit the training loop if no improvement

print("Finished Training")  # Indicate the training process is complete
# Out:
# Epoch 1, Training loss: 0.6425
# Epoch 1, Validation loss: 0.4523
# Epoch 2, Training loss: 0.3169
# Epoch 2, Validation loss: 0.2377
# Epoch 3, Training loss: 0.2479
# Epoch 3, Validation loss: 0.1960
# Epoch 4, Training loss: 0.1978
# Epoch 4, Validation loss: 0.1575
# Epoch 5, Training loss: 0.1669
# Epoch 5, Validation loss: 0.1382
# Epoch 6, Training loss: 0.1421
# Epoch 6, Validation loss: 0.1299
# Epoch 7, Training loss: 0.1240
# Epoch 7, Validation loss: 0.1473
# Epoch 8, Training loss: 0.1058
# Epoch 8, Validation loss: 0.1070
# Epoch 9, Training loss: 0.0872
# Epoch 9, Validation loss: 0.1015
# Epoch 10, Training loss: 0.0845
# Epoch 10, Validation loss: 0.1026
# Epoch 11, Training loss: 0.0700
# Epoch 11, Validation loss: 0.0974
# Epoch 12, Training loss: 0.0653
# Epoch 12, Validation loss: 0.1158
# Epoch 13, Training loss: 0.0501
# Epoch 13, Validation loss: 0.1110
# Epoch 14, Training loss: 0.0410
# Epoch 14, Validation loss: 0.1409
# Epoch 15, Training loss: 0.0333
# Epoch 15, Validation loss: 0.1685
# Epoch 16, Training loss: 0.0330
# Epoch 16, Validation loss: 0.1418
# Epoch 17, Training loss: 0.0220
# Epoch 17, Validation loss: 0.1148
# Epoch 18, Training loss: 0.0163
# Epoch 18, Validation loss: 0.1261
# Epoch 19, Training loss: 0.0164
# Epoch 19, Validation loss: 0.1430
# Early stopping
# Finished Training
# CPU times: user 24.8 s, sys: 9 s, total: 33.8 s
# Wall time: 9min 18s

# %% [markdown]
# ### Visualizing Training Results:
# ###### The training loss graph indicates that the model has effectively learned from the training data, as evidenced by the steady decline in training loss. The validation loss shows a similar downward trend initially, stabilizing afterward, which suggests that the model performs well on unseen data. The implementation of early stopping has prevented overfitting, allowing the model to achieve a balance where its performance on the validation set remains strong without excessive tailoring to the training dataset. Overall, the close alignment between the training and validation loss lines reflects good generalization capabilities of the model.

# %%
def plot_history(train_losses, val_losses):
    plt.figure()  # Create a new figure for the plot
    plt.plot(train_losses, label="train_loss")  # Plot the training losses
    plt.plot(val_losses, label="val_loss")      # Plot the validation losses
    plt.xlabel("Epoch")                         # Label for the x-axis
    plt.ylabel("Loss")                          # Label for the y-axis
    plt.title("Training and Validation Loss")   # Title of the plot
    plt.grid(True)                              # Add a grid for better readability
    plt.legend()                                # Show the legend on the plot
    plt.show()                                  # Display the plot

# Check if 'train_losses' and 'val_losses' exist and are not empty before plotting
if 'train_losses' in globals() and train_losses and 'val_losses' in globals() and val_losses:
    plot_history(train_losses, val_losses)  # Call the plotting function with training and validation losses
else:
    print("Error: 'train_losses' or 'val_losses' not found or is empty. Please run the training cell first.")  # Error message if the lists are unavailable

# %% [markdown]
# ### Saving the Trained Model

# %%
PATH = '/content/drive/MyDrive/Colab_Notebooks/Generated_photo_detector_cnn_final_version/ai_real_net_v7.pth'

# Create the parent directory if it doesn't exist
os.makedirs(os.path.dirname(PATH), exist_ok=True)

torch.save(net.state_dict(), PATH)

# %% [markdown]
# ### Testing the Network on Test Data
# ###### The code initializes a test data iterator, retrieves a batch of test images and their labels, and displays the images while printing the corresponding ground truth labels.

# %%
# Test Data Visualization
dataiter_test = iter(testloader)  # Create an iterator for the test data loader
print("Test Data Iterator:", dataiter_test)  # Print the iterator object for reference
images_test, labels_test = next(dataiter_test)  # Get a batch of test images and their corresponding labels

# Display the test images using the defined imshow function
imshow(torchvision.utils.make_grid(images_test))

# Print the ground truth labels for the displayed test images
print('GroundTruth: ', ' '.join(f'{classes[labels_test[j]]:5s}' for j in range(8)))

# Optionally, visualize validation images
dataiter_val = iter(valloader)  # Create an iterator for the validation data loader
images_val, labels_val = next(dataiter_val)  # Get a batch of validation images and their corresponding labels

# Display the validation images using the defined imshow function
imshow(torchvision.utils.make_grid(images_val))

# Print the ground truth labels for the displayed validation images
print('Validation GroundTruth: ', ' '.join(f'{classes[labels_val[j]]:5s}' for j in range(8)))
# Out:
# Test Data Iterator: <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x79ecbc206a80>
# GroundTruth:  real_color AI    real_color real_color AI    AI    real_color real_color
# Validation GroundTruth:  real_color AI    AI    real_color real_color AI    AI    real_color

# %% [markdown]
# ### Loading the Saved Model and Summary of Architecture
# ##### The code loads the saved model and generates a summary of its architecture, revealing approximately 1.63 million trainable parameters with no non-trainable parameters. It details the output shapes for each layer, including two convolutional layers followed by pooling and three fully connected layers. This information is crucial for understanding the model's complexity and resource requirements, indicating its potential computational demands.

# %%
# Define the path where the model is saved
PATH = '/content/drive/MyDrive/Colab_Notebooks/Generated_photo_detector_cnn_final_version/ai_real_net_v7.pth'

# Initialize the neural network model
net = Net()

# Load the model's weights from the specified path
net.load_state_dict(torch.load(PATH, map_location=device))  # Specify map_location for compatibility

# Move the model to the appropriate device
net.to(device)

# Set the model to evaluation mode
net.eval()  # Important for layers like dropout and batch normalization if they are present

# Display a summary of the model architecture with the corrected input size
summary(net, (3, 128, 128))  # Display the model summary for input size of (3, 128, 128)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 6, 124, 124]             456
#          MaxPool2d-2            [-1, 6, 62, 62]               0
#             Conv2d-3           [-1, 16, 58, 58]           2,416
#          MaxPool2d-4           [-1, 16, 29, 29]               0
#             Linear-5                  [-1, 120]       1,614,840
#             Linear-6                   [-1, 84]          10,164
#             Linear-7                    [-1, 2]             170
# ================================================================
# Total params: 1,628,046
# Trainable params: 1,628,046
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 1.39
# Params size (MB): 6.21
# Estimated Total Size (MB): 7.79
# ----------------------------------------------------------------

# %% [markdown]
# ### Interpreting Model Outputs: Class Predictions
# ##### The model outputs represent the predicted class labels for the input images, demonstrating the network's classifications of each image. These predictions indicate the class to which the model assigns each image, providing insight into its perception and identification capabilities for the given data.

# %%
# Assuming you have run the model on a batch of images
dataiter = iter(testloader)  # Create an iterator for test data
images, labels = next(dataiter)  # Get a batch of test images and their labels
images = images.to(device)  # Move images to the device
net.eval()  # Set the model to evaluation mode

# Forward pass through the network to get outputs
with torch.no_grad():  # Disable gradient calculation for inference
    outputs = net(images)  # Get model predictions

# Get the predicted class indices
_, predicted = torch.max(outputs, 1)

# Print the predicted labels for the first few images in the batch
print('Predicted: ', ' '.join(f'{classes[predicted[j]]:5s}' for j in range(min(4, len(predicted)))))
# Out:
# Predicted:  real_color real_color real_color AI

# %% [markdown]
# ### Evaluating Network Performance on the Entire Dataset
# ###### This section assesses the network's performance on the entire test dataset. It iterates through the test data, generates predictions, and counts the number of correct classifications. Subsequently, it calculates and displays the accuracy of the network on the test images. This evaluation offers valuable insights into the model's effectiveness in classifying unseen data, highlighting its overall performance and reliability.

# %%
correct = 0  # Initialize a counter for correctly classified images
total = 0    # Initialize a counter for the total number of images

# Disable gradient calculation for evaluation
with torch.no_grad():
    for data in testloader:  # Iterate through batches of test data
        images, labels = data  # Get images and their corresponding labels

        # Move inputs to the appropriate device for processing
        images = images.to(device)
        labels = labels.to(device)

        # Calculate outputs by passing images through the network
        outputs = net(images)

        # Determine the predicted class by finding the index of the highest score
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)  # Update the total number of images processed
        correct += (predicted == labels).sum().item()  # Count correct predictions

# Calculate and print the accuracy of the network on the test dataset
accuracy = 100 * correct / total if total > 0 else 0  # Prevent division by zero
print(f'Accuracy of the network on the test images: {accuracy:.2f} %')  # Print accuracy formatted to two decimal places
# Out:
# Accuracy of the network on the test images: 97.15 %

# %% [markdown]
# ###### This section evaluates the network's performance for each class by counting the correct and total predictions, subsequently calculating and displaying the accuracy for each class within the test dataset:

# %%
# prepare to count predictions for each class
correct_pred = {classname: 0 for classname in classes}
total_pred = {classname: 0 for classname in classes}

# again no gradients needed
with torch.no_grad():
    for data in testloader:
        images, labels = data
        # Move inputs to the appropriate device
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[classes[label]] += 1
            total_pred[classes[label]] += 1


# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print(f'Accuracy for class: {classname:5s} is {accuracy:.1f} %')
# Out:
# Accuracy for class: AI    is 97.2 %
# Accuracy for class: real_color is 97.1 %

# %% [markdown]
# # Confusion Matrix:
# #### The confusion matrix indicates that the model performs well, correctly classifying 965 instances of the "AI" class and 969 instances of the "real" class. However, there are 36 "real" images misclassified as "AI" and 32 "AI" images misclassified as "real," highlighting some confusion between the two categories.
#
# #### To improve performance, strategies such as incorporating additional training data, implementing data augmentation, and fine-tuning hyperparameters could be beneficial. While the current results are promising, addressing these misclassification issues can enhance the model's accuracy and reliability in future evaluations.

# %%
# Ensure the model is in evaluation mode and on the correct device
net.eval()
all_labels = []
all_predictions = []

# Disable gradient calculation for efficiency during evaluation
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images = images.to(device)
        labels = labels.to(device)

        outputs = net(images)
        _, predicted = torch.max(outputs, 1)

        all_labels.extend(labels.cpu().numpy())
        all_predictions.extend(predicted.cpu().numpy())

# Calculate the confusion matrix
cm = confusion_matrix(all_labels, all_predictions)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ### Evaluating Model Performance on an Out-of-Dataset Images:
# ###### TThis code establishes the model architecture and includes functions to load a trained model, preprocess multiple input images from a specified folder, and predict their classes based on the model's outputs. This enhancement allows for evaluating the model on an entire set of images not present in the original dataset, providing understanding of the model's performance on unseen data.

# %%
# Step 1: Define the EXACT model architecture from training
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)  # First convolutional layer
        self.pool = nn.MaxPool2d(2, 2)  # Max pooling layer
        self.conv2 = nn.Conv2d(6, 16, 5)  # Second convolutional layer
        self.fc1 = nn.Linear(16 * 29 * 29, 120)  # First fully connected layer
        self.fc2 = nn.Linear(120, 84)  # Second fully connected layer
        self.fc3 = nn.Linear(84, 2)  # Output layer for 2 classes

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))  # Apply first conv layer and pooling
        x = self.pool(F.relu(self.conv2(x)))  # Apply second conv layer and pooling
        x = torch.flatten(x, 1)  # Flatten all dimensions except batch
        x = F.relu(self.fc1(x))  # Forward pass through first fully connected layer
        x = F.relu(self.fc2(x))  # Forward pass through second fully connected layer
        x = self.fc3(x)  # Output layer
        return x

# Step 2: Load the trained model
def load_model(model_path, device='cpu'):
    """Load the trained model from .pth file"""
    model = Net().to(device)  # Initialize model and move to specified device
    model.load_state_dict(torch.load(model_path, map_location=device))  # Load the model's weights
    model.eval()  # Set the model to evaluation mode
    return model

# Step 3: Preprocess the image (CRITICAL: Must be 128x128!)
def preprocess_image(image_path, target_size=(128, 128)):
    """Load and preprocess a single image"""
    transform = transforms.Compose([
        transforms.Resize(target_size),  # Resize image to target size
        transforms.ToTensor(),           # Convert image to tensor
        transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])  # Normalization
    ])

    image = Image.open(image_path).convert('RGB')  # Open and convert image to RGB
    image_tensor = transform(image).unsqueeze(0)  # Add batch dimension
    return image_tensor

# Step 4: Make prediction
def predict(model, image_tensor, device='cpu'):
    """Run inference on the preprocessed image"""
    image_tensor = image_tensor.to(device)  # Move tensor to the appropriate device

    with torch.no_grad():  # Disable gradient computation
        outputs = model(image_tensor)  # Get model outputs
        probabilities = torch.softmax(outputs, dim=1)  # Convert outputs to probabilities
        predicted_class = torch.argmax(probabilities, dim=1)  # Get the predicted class index

    return predicted_class.item(), probabilities[0].cpu().numpy()  # Return predictions

# Step 5: Main testing function for the folder of images
def test_image_folder(model_path, image_folder, class_labels=None, device=None):
    """Complete pipeline to test model on a folder of images and count predictions"""
    if device is None:
        device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print(f"Using device: {device}")

    if class_labels is None:
        class_labels = {
            0: "AI-Generated",  # AI
            1: "Real Photo",  # Real
        }

    print(f"Loading model from {model_path}...")
    model = load_model(model_path, device)

    # Counters for predictions
    ai_generated_count = 0
    real_photo_count = 0

    # Loop through all images in the specified folder
    for image_file in os.listdir(image_folder):
        #if image_file.lower().endswith(('.png', '.jpg', '.jpeg', '.avif')):  # Check for valid image extensions
        image_path = os.path.join(image_folder, image_file)
        print(f"Processing image: {image_path}")

        image_tensor = preprocess_image(image_path)

        print("Running inference...")
        predicted_class, probabilities = predict(model, image_tensor, device)

        # Count predictions
        if predicted_class == 0:  # AI-Generated
            ai_generated_count += 1
        elif predicted_class == 1:  # Real Photo
            real_photo_count += 1

    # Display the total counts of predictions
    print("\n" + "="*60)
    print("TOTAL PREDICTIONS:")
    print("="*60)
    print(f"Total AI-Generated Photos: {ai_generated_count}")
    print(f"Total Real Photos: {real_photo_count}")
    print("="*60)

# Example usage
if __name__ == "__main__":
    CLASS_LABELS = {
        0: "AI-Generated",  # AI
        1: "Real Photo",    # Real
    }

    MODEL_PATH = "/content/drive/MyDrive/Colab_Notebooks/Generated_photo_detector_cnn_final_version/ai_real_net_v7.pth"
    IMAGE_FOLDER = "/content/drive/MyDrive/Colab_Notebooks/Generated_photo_detector_cnn_final_version/photos_outside_dataset/ai_outside_dataset"

    try:
        test_image_folder(MODEL_PATH, IMAGE_FOLDER, class_labels=CLASS_LABELS)

    except FileNotFoundError as e:
        print(f"Error: {e}")
        print("Please check that the model and image folder paths are correct.")
    except Exception as e:
        print(f"An error occurred: {e}")
        import traceback
        traceback.print_exc()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2694236298.py in <cell line: 0>()
#       1 # Step 1: Define the EXACT model architecture from training
# ----> 2 class Net(nn.Module):
#       3     def __init__(self):
#       4         super().__init__()
#       5         self.conv1 = nn.Conv2d(3, 6, 5)  # First convolutional layer
#
# NameError: name 'nn' is not defined

# %% [markdown]
# ##### CONCLUSION: The model has demonstrated substantial improvement in its performance on out-of-dataset images. It successfully recognized 40 out of 49 real photographs (82% accuracy), a remarkable increase from its previous performance of zero. Additionally, it achieved an impressive 100% accuracy on AI-generated out-of-dataset images.
# ##### Consequently, the overall accuracy on unseen data stands at 89%.
